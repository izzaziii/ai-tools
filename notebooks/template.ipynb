# %% [markdown]
# # Title of the Notebook
# - Date:
# - Purpose:
#
# ## Notebook Setup
# - Business question:
# - Expected outcomes:
# - Assumptions or constraints:

# %% [markdown]
# Notebook environment setup

# %%
import os
import sys

def set_working_directory(path: str) -> None:
    """
    Set the working directory and add it to sys.path for module imports.

    Args:
        path (str): The path to set as the working directory.

    Raises:
        FileNotFoundError: If the specified path does not exist.
    """
    if not os.path.isdir(path):
        raise FileNotFoundError(f"Directory '{path}' does not exist.")
    os.chdir(path)
    if path not in sys.path:
        sys.path.insert(0, path)

# Example usage:
set_working_directory(r"G:\GitHub Repos\ai-tools")

src_path = os.path.join(os.getcwd(), "src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# %% [markdown]
# Visualization params and styling

# %%
import matplotlib.pyplot as plt
plt.style.use(['seaborn-v0_8-notebook', 'seaborn-v0_8-white'])

# %% [markdown]
# Get Data

# %%
import pandas as pd
import utils.ga4 as ga

df = ga.get_ols_dataframe(start_date="7daysAgo", end_date="yesterday")
df
# Out:
#           traffic  view_item  type_addr  add_contact  add_addr  add_date  \
# date
# 20250417    22048        738        194          147       123        79
# 20250416    21948        789        201          150       132        81
# 20250415    21182        848        232          169       143        88
# 20250414    22513        946        259          190       148        95
# 20250413    20279        594        166          101        89        60
# 20250412    21726        623        173          115        92        50
# 20250411    25403        810        215          134       118        68
#
#           checkout  purchase
# date
# 20250417        75        45
# 20250416        75        48
# 20250415        92        56
# 20250414        88        65
# 20250413        53        37
# 20250412        43        32
# 20250411        67        46

# %% [markdown]
# Comment on it

# %%
from core.openai_client import OpenAIClient

json_data = df.to_dict(orient="records")

client = OpenAIClient()
prompt = f"You are an experienced data analyst. Comment on your observations of the e-commerce website data. Dataset:{json_data}"
response = client.get_completion(prompt)
print(response["tokens"])
print(response["text"])
# Out:
# {'input': 405, 'output': 611, 'total': 1016}
# Based on the provided e-commerce website data across seven time periods (or different segments), here are some observations and insights:
#
# 1. **Traffic vs Engagement:**
#    - Overall traffic ranges from about 20,279 to 25,403 visitors.
#    - Despite relatively stable traffic numbers, engagement metrics such as "view_item" vary quite a bit – from as low as 594 up to 946.
#    - This suggests that traffic alone does not guarantee proportional user interaction with items. There may be variability in how visitors browse the catalog.
#
# 2. **Funnel Drop-off:**
#    - Starting from "view_item", the numbers drop at every subsequent step:
#      - "type_addr" (users typing address): ranges from 166 to 259.
#      - "add_contact" (adding contact info): ranges from 101 to 190.
#      - "add_addr" (adding address): ranges from 89 to 148.
#      - "add_date" (adding date): from 50 to 95.
#      - "checkout": from 43 to 92.
#      - "purchase": from 32 to 65.
#    - The highest drop-offs appear between "traffic" to "view_item" (less than 5% conversion) and also a noticeable drop from "checkout" to "purchase" (roughly 50-70% completion rate from checkout to purchase).
#
# 3. **Conversion Ratios:**
#    - Conversion from traffic to purchase is quite low (about 0.15% to 0.3%), which might be typical but suggests room for improving user journey or marketing targeting.
#    - The percentage of people who start checkout and finish a purchase ranges approximately from 42% (32/75) to 87% (65/75) in different segments. This indicates checkout could be optimized further to close more sales.
#
# 4. **Trends and Outliers:**
#    - Entry with traffic 25,403 has relatively lower "view_item" and final purchase compared to traffic, indicating lower quality or less interested visitors for that period.
#    - Conversely, the period with 22,513 traffic has the highest view_item (946) and the highest purchase (65), reflecting more engaged traffic.
#
# 5. **Recommendations for Improvement:**
#    - Investigate why visitors are not viewing items despite high traffic — analyze homepage, landing pages, or ad targeting.
#    - Optimize the checkout and address input processes since user drop-off is visible at these steps.
#    - Consider engagement tactics such as item recommendations or better UX to increase "view_item" and "add_contact" usage.
#    - A/B testing for checkout flows could help reduce drop-off and increase purchase rates.
#    - Further segmentation analysis (device, user source, product type) would provide deeper insights.
#
# **Summary:**
# Traffic volume appears stable, but engagement fluctuates and conversion to purchase is low, highlighting potential UX or targeting issues. Focus should be on improving item discovery and completing checkout to drive higher conversion rates.
